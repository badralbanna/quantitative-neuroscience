# %% [markdown]
# # Exercise 6: Correlation and casuation
#
# In this series of excersies we'll look at how to calculate basic measures of correlation in python and use the `causalgraphicalmodels` package to explore graphical models
#
#
# ## Table of Contents
#
# * Correlation
#     * Pearson's correlation ($r$)
#     * Spearman's correlation ($s$)
# * Causation
#
#
# ## Setup

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import os

# For retina displays only 
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
# %matplotlib inline

# %% [markdown]
# ## Correlation

# %%
# Creating some data
N = 500 # number of samples
X = np.random.normal(loc=3.0, scale=5.0, size=N)
noise = np.random.normal(loc=0, scale=7.0, size=N)
Y = 2.2*X + noise

# %%
# Always plot your data
fig = plt.figure(figsize=(5,5))
gs = fig.add_gridspec(2, 2, width_ratios=[1, .1], height_ratios=[.1, 1])
ax = fig.add_subplot(gs[1, 0])
ax_histx = fig.add_subplot(gs[0, 0], sharex=ax)
ax_histy = fig.add_subplot(gs[1, 1], sharey=ax)
ax.scatter(X, Y)
ax_histx.hist(X, bins=100)
ax_histy.hist(Y, bins=100, orientation='horizontal')
plt.tight_layout()

# %% [markdown]
# ### Pearson's correlation ($r$)

# %%
# using numpy
np.corrcoef(X, Y)
# Out:
# array([[1.        , 0.83802834],
#        [0.83802834, 1.        ]])

# %%
# using scipy.stats
import scipy.stats

scipy.stats.pearsonr(X, Y)
# Out:
# (0.8380283350798596, 4.0133046493638796e-133)

# %%
# Using pandas
df = pd.DataFrame({'x': X, 'y': Y})

df.corr(method='pearson')
# Out:
#           x         y
# x  1.000000  0.838028
# y  0.838028  1.000000

# %% [markdown]
# ### Spearman's correlation ($s$)

# %%
# using scipy.stats
scipy.stats.spearmanr(X, Y)
# Out:
# SpearmanrResult(correlation=0.8196424465697862, pvalue=1.4224527768223955e-122)

# %%
# Using pandas
df = pd.DataFrame({'x': X, 'y': Y})

df.corr(method="spearman")
# Out:
#           x         y
# x  1.000000  0.819642
# y  0.819642  1.000000

# %%
# verifying that what I said was true
scipy.stats.pearsonr(scipy.stats.rankdata(X), scipy.stats.rankdata(Y))
# Out:
# (0.8196424465697862, 1.422452776821959e-122)

# %%
# Excerise 1: Demonstrate that sample size changes p value but not correlation

# %%
# Excerise 2: Play around with different X Y associations and calculate $r$ and $s$

# %% [markdown]
# ## Causation
